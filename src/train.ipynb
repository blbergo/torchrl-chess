# %%
from model import Model

model = Model()
model.train()
# Out:
# observation shape: 218, action space: 29275
# /home/bryan/github/cpp/CS4200/chess/.venv/lib/python3.12/site-packages/torch/_compile.py:51: UserWarning:
#
# optimizer contains a parameter group with duplicate parameters; in future, this will cause an error; see github.com/pytorch/pytorch/issues/40967 for more information
# Episode 1/100 - Loss: -1.5659
# Episode 2/100 - Loss: -0.5000
# Episode 3/100 - Loss: -0.5000
# Episode 4/100 - Loss: 1043.0725
# Episode 5/100 - Loss: 2298.9924
# Episode 6/100 - Loss: 2483.9722
# Episode 7/100 - Loss: 2021.5338
# Episode 8/100 - Loss: 1195.9957
# Episode 9/100 - Loss: 244.3814
# Episode 10/100 - Loss: -0.5000
# Episode 11/100 - Loss: -0.5000
# Episode 12/100 - Loss: -0.5000
# Episode 13/100 - Loss: -0.5000
# Episode 14/100 - Loss: 58.6866
# Episode 15/100 - Loss: 565.4540
# Episode 16/100 - Loss: 919.1078
# ---------------------------------------------------------------------------
# ...

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv(f"./runs/latest/logs.csv")
df["loss"].describe()
# Out:
# count     501
# unique    202
# top       0.0
# freq      300
# Name: loss, dtype: object

# %%
px.line(
    df,
    x="episode",
    y="loss",
    color="type",
    title="PPO Loss over Episodes",
    labels={"episode": "Episode", "loss": "Loss"},
).show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 px.line(
#       2     df,
#       3     x="episode",
#       4     y="loss",
#       5     color="type",
#       6     title="PPO Loss over Episodes",
#       7     labels={"episode": "Episode", "loss": "Loss"},
#       8 ).show()
#
# ...
